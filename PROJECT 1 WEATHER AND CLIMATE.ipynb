# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "D:\DOWNLOADS\tas_climatology_annual-monthly_cru_1991-2020_IND.csv"
wdr_data = pd.read_csv("D:/DOWNLOADS/tas_climatology_annual-monthly_cru_1991-2020_IND.csv")
wdr_data2= pd.read_csv("D:/DOWNLOADS/Weather Data in India from 1901 to 2017.csv")
rain_data=pd.read_csv("D:/DOWNLOADS/Rainfall-_1901_to_2019_0.csv")
min_data = pd.read_csv("D:/DOWNLOADS/Min_Temp_IMD_2017.csv")
wdr_data.head()
# Out:
#                  State    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0  Andaman and Nicobar  26.55  26.72  27.48  28.47  28.07  27.39  27.07
# 1       Andhra Pradesh  23.65  26.20  29.20  31.68  33.10  30.81  28.58
# 2    Arunachal Pradesh  11.48  13.41  16.35  18.75  21.29  23.38  23.80
# 3                Assam  16.43  18.59  22.17  24.02  25.54  27.03  27.40
# 4                Bihar  16.63  19.39  24.62  29.09  31.08  31.13  29.40
#
#      Aug    Sep  ...  Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  \
# 0  27.05  26.85  ...          NaN          NaN          NaN          NaN
# 1  28.00  28.11  ...          NaN          NaN          NaN          NaN
# 2  23.98  23.01  ...          NaN          NaN          NaN          NaN
# 3  27.66  27.03  ...          NaN          NaN          NaN          NaN
# 4  29.21  28.82  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  Unnamed: 34  \
# ...

# %%
list(wdr_data.columns)
# Out:
# ['State',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec',
#  'Annual',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35']

# %%
#DROP CERTAIN COLUMNS, SET INDEX COLUMN, DROP ROWS WITH NA VALUE
wdr_data.drop(['Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35'], axis=1, inplace=True)
wdr_data.set_index("State",inplace=True)
wdr_data.dropna(axis = 0, inplace=True)
print(wdr_data)
# Out:
#                           Jan    Feb    Mar    Apr    May    Jun    Jul  \
# State
# Andaman and Nicobar     26.55  26.72  27.48  28.47  28.07  27.39  27.07
# Andhra Pradesh          23.65  26.20  29.20  31.68  33.10  30.81  28.58
# Arunachal Pradesh       11.48  13.41  16.35  18.75  21.29  23.38  23.80
# Assam                   16.43  18.59  22.17  24.02  25.54  27.03  27.40
# Bihar                   16.63  19.39  24.62  29.09  31.08  31.13  29.40
# Chandigarh              12.81  15.83  20.96  26.88  30.93  31.96  29.94
# Chhattisgarh            19.47  22.59  26.92  30.90  33.43  31.03  27.30
# Dadra and Nagar Haveli  22.10  23.67  26.91  29.38  30.70  29.21  27.01
# Daman and Diu           21.98  23.27  25.99  27.86  29.51  29.74  28.23
# Delhi                   14.29  17.56  23.13  29.23  32.88  33.57  31.11
# Goa                     25.19  26.10  27.98  29.41  29.65  27.28  26.06
# Gujarat                 20.12  22.60  27.04  30.66  32.76  31.88  29.28
# ...

# %%
#TRANSPOSE TABLE, REMOVE ANNUAL COLUMN
wdr_data_new = wdr_data.T
wdr_data_new.drop(['Annual'],inplace=True)
print(wdr_data_new)
# Out:
# State  Andaman and Nicobar  Andhra Pradesh  Arunachal Pradesh  Assam  Bihar  \
# Jan                  26.55           23.65              11.48  16.43  16.63
# Feb                  26.72           26.20              13.41  18.59  19.39
# Mar                  27.48           29.20              16.35  22.17  24.62
# Apr                  28.47           31.68              18.75  24.02  29.09
# May                  28.07           33.10              21.29  25.54  31.08
# Jun                  27.39           30.81              23.38  27.03  31.13
# Jul                  27.07           28.58              23.80  27.40  29.40
# Aug                  27.05           28.00              23.98  27.66  29.21
# Sep                  26.85           28.11              23.01  27.03  28.82
# Oct                  27.11           27.26              20.36  25.22  27.04
# Nov                  27.54           25.13              16.07  21.38  22.54
# ...

# %%
plt.figure(figsize=[10,5])
sns.lineplot(data=wdr_data_new["West Bengal"],label="Bengal")
sns.lineplot(data=wdr_data_new["Rajasthan"],label="Rajasthan")
plt.xlabel('Months')
plt.ylabel('Temperature')
plt.grid()

# %%
#ROTATE THE X LABEL TICKS, DRAW AVERAGE TEMPERATURE LINE
plt.figure(figsize=[20,5])

graph=sns.barplot(x=wdr_data.index, y=wdr_data["Annual"])
plt.xlabel('State')
plt.ylabel('Avg. Temperature')
plt.xticks(rotation=90)
mean=wdr_data.Annual.mean()
graph.axhline(mean) , #DRAW AVERAGE TEMPERATURE LINE
# Out:
# (<matplotlib.lines.Line2D at 0x268a3423dc0>,)

# %%
wdr_data2.head()
wdr_data2.set_index("YEAR", inplace= True)
wdr_data2.head()
# Out:
#       Unnamed: 0    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# YEAR
# 1901           0  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1902           1  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 1903           2  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 1904           3  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 1905           4  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#         SEP    OCT    NOV    DEC
# YEAR
# 1901  26.26  25.08  21.73  18.95
# 1902  25.95  24.37  21.33  18.78
# 1903  26.34  24.57  20.96  18.29
# 1904  25.84  24.36  21.07  18.84
# 1905  26.29  26.16  22.07  18.71

# %%
wdr_data2.tail()
# Out:
#       Unnamed: 0    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# YEAR
# 2013         112  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 2014         113  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 2015         114  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 2016         115  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 2017         116  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
#         SEP    OCT    NOV    DEC
# YEAR
# 2013  26.87  25.63  22.18  19.69
# 2014  26.61  25.38  22.53  19.50
# 2015  27.04  25.82  22.95  20.21
# 2016  27.72  26.81  23.90  21.89
# 2017  28.11  27.24  23.92  21.47

# %%
wdr_data2.drop(["Unnamed: 0"],axis=1,inplace=True)
wdr_data2.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#         NOV    DEC
# YEAR
# 1901  21.73  18.95
# 1902  21.33  18.78
# 1903  20.96  18.29
# 1904  21.07  18.84
# 1905  22.07  18.71

# %%
plt.figure(figsize=(20,8))
plt.plot(wdr_data2.index,wdr_data2["JAN"],label="January")
plt.plot(wdr_data2.index,wdr_data2["DEC"],label="December")
#plt.plot(wdr_data2.index,wdr_data2)
plt.grid()
plt.legend()

# %%
rain_data.head()
rain_data.set_index("YEAR",inplace=True)

# %%
plt.figure(figsize=(20,8))
plt.plot(rain_data.index,rain_data["JUN-SEP"])
plt.grid()

# %%
#COMBINE RAIN DATA AND WDR DAta2

# %%
wdr_data2.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#         NOV    DEC
# YEAR
# 1901  21.73  18.95
# 1902  21.33  18.78
# 1903  20.96  18.29
# 1904  21.07  18.84
# 1905  22.07  18.71

# %%
wdr_data2_new = wdr_data2.drop(["JAN","FEB","MAR","APR","MAY","OCT","NOV","DEC"],axis=1)
wdr_data2_new.tail()
# Out:
#         JUN    JUL    AUG    SEP
# YEAR
# 2013  28.24  27.50  27.22  26.87
# 2014  29.42  28.07  27.42  26.61
# 2015  28.15  28.03  27.64  27.04
# 2016  29.70  28.18  28.17  27.72
# 2017  29.44  28.31  28.12  28.11

# %%
rain_data.tail()
# Out:
#         JUN    JUL    AUG    SEP  JUN-SEP
# YEAR
# 2015  188.9  240.7  204.1  131.7    765.4
# 2016  147.0  308.4  239.4  168.8    863.7
# 2017  171.9  290.5  228.3  153.0    843.7
# 2018  155.7  273.8  240.5  132.3    802.4
# 2019  112.9  296.7  299.3  260.4    969.4

# %%
#DELETING ROWS
new_rain_data=rain_data.drop([2018,2019],axis=0)
new_rain_data.drop(["JUN-SEP"],axis=1)
# Out:
#         JUN    JUL    AUG    SEP
# YEAR
# 1901  111.0  243.2  273.6  124.6
# 1902  109.0  282.8  201.8  201.0
# 1903  117.0  292.0  271.7  200.9
# 1904  165.2  263.1  205.2  131.7
# 1905   92.3  254.9  201.4  180.0
# ...     ...    ...    ...    ...
# 2013  221.1  311.5  258.0  155.1
# 2014   92.8  266.7  234.6  190.1
# 2015  188.9  240.7  204.1  131.7
# 2016  147.0  308.4  239.4  168.8
# 2017  171.9  290.5  228.3  153.0
#
# [117 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
#plt.figure(figsize=(6,6))
plt.plot(new_rain_data.index,new_rain_data["JUN"] )

plt.xlabel("JUNE")
plt.ylabel("Rainfal in MM")
plt.grid()

plt.subplot(2,2,2)
#plt.figure(figsize=(6,6))
plt.plot(new_rain_data.index,new_rain_data["JUL"] )
plt.xlabel("JULY")
plt.ylabel("Rainfal in MM")
plt.grid()

plt.subplot(2,2,3)
#plt.figure(figsize=(6,6))
plt.plot(new_rain_data.index,new_rain_data["AUG"] )
plt.xlabel("AUGUST")
plt.ylabel("Rainfal in MM")
plt.grid()

plt.subplot(2,2,4)
plt.plot(new_rain_data.index,new_rain_data["SEP"] )
plt.xlabel("SEPTEMBER")
plt.ylabel("Rainfal in MM")
plt.grid()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)

#USING NUMPY CREATE A HORIZONTAL MATRIX AND MULTIPLY IT WITH THE MEAN CALCULATED, NECESSARY FOR PLOTTING
mean = wdr_data2_new["JUN"].mean()
mean_arr = np.ones(117) * mean 
plt.plot(wdr_data2_new.index,mean_arr,label = 'Average rainfall for the Month')
plt.plot(wdr_data2_new.index,wdr_data2_new["JUN"])
plt.xlabel("JUNE")
plt.ylabel("Temperature")
plt.grid()

plt.subplot(2,2,2)
mean = wdr_data2_new["JUL"].mean()
mean_arr = np.ones(117) * mean 
plt.plot(wdr_data2_new.index,mean_arr,label = 'Average rainfall for the Month')
plt.plot(wdr_data2_new.index,wdr_data2_new["JUL"])
plt.xlabel("JULY")
plt.ylabel("Temperature")
plt.grid()

plt.subplot(2,2,3)
mean = wdr_data2_new["AUG"].mean()
mean_arr = np.ones(117) * mean 
plt.plot(wdr_data2_new.index,mean_arr,label = 'Average rainfall for the Month')
plt.plot(wdr_data2_new.index,wdr_data2_new["AUG"])
plt.xlabel("AUGUST")
plt.ylabel("Temperature")
plt.grid()

plt.subplot(2,2,4)
mean = wdr_data2_new["SEP"].mean()
mean_arr = np.ones(117) * mean 
plt.plot(wdr_data2_new.index,mean_arr,label = 'Average rainfall for the Month')
plt.plot(wdr_data2_new.index,wdr_data2_new["SEP"])
plt.xlabel("SEPTEMBER")
plt.ylabel("Temperature")
plt.grid()

# %%
#SCATTER PLOT FROM COMBINED DATA USING PYPLOT
plt.figure(figsize=(20,10))
plt.scatter(wdr_data2_new["JUN"],new_rain_data["JUN"],label="June")
plt.scatter(wdr_data2_new["JUL"],new_rain_data["JUL"],label="July")
plt.scatter(wdr_data2_new["AUG"],new_rain_data["AUG"],label="August")
plt.scatter(wdr_data2_new["SEP"],new_rain_data["SEP"],label="September")
plt.grid()
plt.xlabel("Temperature", size = 16)
plt.ylabel("Rainfall in mm", size = 16)
plt.legend()

# %%
#SCATTER PLOT FROM COMBINED DATA USING SEABORN
plt.figure(figsize=(20,10))
sns.regplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June")
sns.regplot(x=wdr_data2_new["JUL"],y=new_rain_data["JUL"],label="July")
sns.regplot(x=wdr_data2_new["AUG"],y=new_rain_data["AUG"],label="August")
sns.regplot(x=wdr_data2_new["SEP"],y=new_rain_data["SEP"],label="September")
plt.grid()
plt.xlabel("Temperature", size = 16)
plt.ylabel("Rainfall in mm", size = 16)
plt.legend()

# %%
#REGRESSION PLOT FOR SAME

plt.subplot(2,2,1)
#sns.scatterplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June",size=new_rain_data.index,legend=False)
sns.regplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],color='Orange')
plt.xlabel("temp")
plt.ylabel("rain")
plt.grid()

plt.subplot(2,2,2)
#sns.scatterplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June",size=new_rain_data.index,legend=False)
sns.regplot(x=wdr_data2_new["JUL"],y=new_rain_data["JUL"])
plt.xlabel("temp")
plt.ylabel("rain")
plt.grid()

plt.subplot(2,2,3)
#sns.scatterplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June",size=new_rain_data.index,legend=False)
sns.regplot(x=wdr_data2_new["AUG"],y=new_rain_data["AUG"],color='Red')
plt.xlabel("temp")
plt.ylabel("rain")
plt.grid()

plt.subplot(2,2,4)
#sns.scatterplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June",size=new_rain_data.index,legend=False)
sns.regplot(x=wdr_data2_new["SEP"],y=new_rain_data["SEP"],color='Green')
plt.xlabel("temp")
plt.ylabel("rain")
plt.grid()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],label="June",hue=wdr_data2_new.index,legend=False)
#sns.regplot(x=wdr_data2_new["JUN"],y=new_rain_data["JUN"],color='Orange')

plt.xlabel("temp")
plt.ylabel("rain")
plt.grid()

# %%
wdr_data2_new["SEP"].mean()
# Out:
# 26.342649572649577
